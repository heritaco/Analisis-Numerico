# %% [markdown]
# # Resolviendo EDOs con Python

# %% [markdown]
# **Nombre:** Heriberto Espino Montelongo
#
# **Materia:** Análisis numérico
#
# **Sección:** 1
#
# **Fecha:** 07/11/2024

# %% [markdown]
# # Instrucciones

# %% [markdown]
# Considerando el problema de valor inicial (PVI):
#
# Resolver:
# $$
# \frac{dy}{dt} = f(t, y)
# $$
# Sujeta a:
# $$
# y(t_0) = y_0
# $$

# %% [markdown]
# # Funciones

# %%
import matplotlib.pyplot as plt
import mpld3
from IPython.display import display, HTML

import numpy as np
import sympy as sp
from sympy.abc import x 

from matplotlib.backends.backend_pdf import PdfPages

from prettytable import PrettyTable

# %%
all_figures = []

# %%
def plot_solution(t, y, fig_title, color):

    global all_figures  # Use global to store figures across multiple calls

    fig = plt.figure(figsize=(8, 6), dpi=1920) 
    plt.plot(t, y,'o', alpha=0.9, color=color)
    plt.title(fig_title, fontsize=14, fontweight='bold')
    plt.grid()
    plt.xlabel('t')
    plt.ylabel('y')

    display(HTML(mpld3.fig_to_html(plt.gcf()))) # Display the plot as HTML
    plt.close() # Close the plot to prevent it from displaying twice

    all_figures.append(fig) # Store the figure to save it later
    
    return

# %%
def exact_solution(name, function, lower_bound, upper_bound, h, plot = False):

    f = sp.lambdify(x,function)
    n = int((upper_bound-lower_bound)/h)
    t = np.linspace(lower_bound,upper_bound,n+1)
    y = f(t)

    if plot:
        plot_solution(t, y, 'Heri - Exact Solution - ' + str(name), '#B65A5A')

    return t, y

# %%
def euler(name, f, t0, tn, h, y0, plot = False):

    n = int(abs(tn - t0) / h)
    t = np.linspace(t0, tn, n + 1)
    y = np.zeros(n + 1)
    y[0] = y0
    for k in range(n):
        y[k + 1] = y[k] + h * f(t[k], y[k])

    if plot:
        plot_solution(t, y, 'Heri - Euler\'s method - ' + str(name), '#1A5465')

    return t, y

# %%
def RK4(name, f, t0, tn, h, y0, plot = False):

    n = int(abs(tn - t0) / h)
    t = np.linspace(t0, tn, n + 1)
    y = np.zeros(n + 1)
    y[0] = y0
    
    for i in range(n):
        s1 = f(t[i], y[i])
        s2 = f(t[i] + h / 2, y[i] + s1 * h / 2)
        s3 = f(t[i] + h / 2, y[i] + s2 * h / 2)
        s4 = f(t[i] + h, y[i] + s3 * h)
        y[i + 1] = y[i] + h * (s1 + 2 * s2 + 2 * s3 + s4) / 6

    if plot:
        plot_solution(t, y, 'Heri - RK4 method - ' + str(name), '#1A5465')

    return t, y

# %%
def compare_methods(name, function, f, t0, tn, h, y0):

    t_exact, y_exact = exact_solution(name, function, t0, tn, h)
    t_euler, y_euler = euler(name, f, t0, tn, h, y0)
    t_rk4, y_rk4 = RK4(name, f, t0, tn, h, y0)

    global all_figures

    fig = plt.figure(figsize=(5, 3), dpi=150) 
    plt.plot(t_exact, y_exact, '-', label=f"Exact solution: {y_exact[-1]:.2f}", color='#50A3A4', alpha=0.5, lw = 4)
    plt.plot(t_euler, y_euler, 's--', label=f"Euler's Method: {y_euler[-1]:.2f}", color='#FCAF38', alpha=0.5)
    plt.plot(t_rk4, y_rk4, 'o--', label=f"RK4 Method: {y_rk4[-1]:.2f}", color='#F95335', alpha=0.5)
    plt.title('Comparison of Methods - ' + str(name), fontsize=14, fontweight='bold')
    plt.xlabel('t')
    plt.ylabel('y')
    plt.legend()
    plt.grid()

    display(HTML(mpld3.fig_to_html(plt.gcf())))
    plt.close()

    all_figures.append(fig)
    
    return

# %%
def euler_vs_RK4(name, f, t0, tn, h, y0, plot = False, table = False, final_results = False):

    t_euler, y_euler = euler(name, f, t0, tn, h, y0)
    t_rk4, y_rk4 = RK4(name, f, t0, tn, h, y0)

    if table:
        myTable = PrettyTable(["x_i", "y_i Euler", "y_i RK4"])
        myTable.title = "Euler vs RK4 " + str(name)

        for i in range(len(t_euler)):
            myTable.add_row([
                round(t_euler[i], 2), 
                round(y_euler[i], 2), 
                round(y_rk4[i], 2), 
            ])

        display(HTML(myTable.get_html_string()))

    if plot:
        global all_figures

        fig = plt.figure(figsize=(5, 3), dpi=150) 
        plt.plot(t_euler, y_euler, 's-', label=f"Euler's Method: {y_euler[-1]:.2f}", color='#1A5465', alpha=0.5)
        plt.plot(t_rk4, y_rk4, 'd-', label=f'RK4 Method: {y_rk4[-1]:.2f}', color='#2A9D8F', alpha=0.5)
        plt.title('Euler vs RK4 - ' + str(name), fontsize=14, fontweight='bold')
        plt.xlabel('t')
        plt.ylabel('y')
        plt.legend()
        plt.grid()
        
        display(HTML(mpld3.fig_to_html(plt.gcf())))
        plt.close()

        all_figures.append(fig)

    return

# %%
def error_euler(name, f, function, t0, tn, h, y0):

    t_exact, y_exact = exact_solution(name, f, t0, tn, h)
    t_euler, y_euler = euler(name, function, t0, tn, h, y0)
    
    myTable = PrettyTable(["x_i", "y_i Exact", "y_i Euler", "Absolute E", "Relative E"])
    myTable.title = "Error Analysis for Euler  " + str(name)

    for i in range(len(t_exact)):
        myTable.add_row([
            round(t_exact[i], 4), 
            round(y_exact[i], 4), 
            round(y_euler[i], 4), 
            round(abs(y_exact[i] - y_euler[i]), 4), 
            round(abs(y_exact[i] - y_euler[i]) / y_exact[i], 4)
        ])

    display(HTML(myTable.get_html_string()))

# %%
def error_rk4(name, f, function, t0, tn, h, y0):

    t_exact, y_exact = exact_solution(name, f, t0, tn, h)
    t_rk4, y_rk4 = RK4(name, function, t0, tn, h, y0)

    myTable = PrettyTable(["x_i", "y_i Exact", "y_i RK4", "Absolute E", "Relative E"])
    myTable.title = "Error Analysis for RK4  " + str(name)

    for i in range(len(t_exact)):
        myTable.add_row([
            round(t_exact[i], 2), 
            round(y_exact[i], 2), 
            round(y_rk4[i], 2), 
            round(abs(y_exact[i] - y_rk4[i]), 4), 
            round(abs(y_exact[i] - y_rk4[i]) / y_rk4[i], 4)
        ])
        
    display(HTML(myTable.get_html_string()))

# %%
def multipage(filename, figs=None, dpi=150):
    pp = PdfPages(filename)
    if figs is None:
        figs = [plt.figure(n) for n in plt.get_fignums()]  # Fallback: get all open figures
    for fig in figs:
        # Save each figure with tight layout and specified dpi to control size
        fig.savefig(pp, format='pdf', dpi=dpi, bbox_inches='tight')
    pp.close()

# %% [markdown]
# # Ejercicio 1

# %% [markdown]
# Si se invierten $10,000 dólares a una tasa de interés del 3% anual, capitalizada semestralmente, encuentra el valor de la inversión después del número dado de años. Primero utiliza el método de Euler y luego el método RK4. Grafica la solución numérica con ambos métodos. Superpone ambas curvas de solución en el mismo sistema de coordenadas. Si es posible, utiliza un color diferente para cada curva. Interpreta la solución.
#    - a) 5 años
#    - b) 10 años
#    - c) 15 años

# %%
def i(t, y):
    return 0.03 * y

t0 = 0 
y0 = 10000
h = 0.5

# %% [markdown]
# ### Para 5 años

# %%
tn = 5
name = f"Ejercicio 1 - Inversión a {tn} años - h = {h}"

# %%
euler_vs_RK4(name, i, t0, tn, h, y0, plot=True)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1031612900424268161281742260"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1031612900424268161281742260", {"width": 750.0, "height": 450.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-0.25, 5.25], "ylim": [9919.082878672163, 11699.259547884578], "xdomain": [-0.25, 5.25], "ydomain": [9919.082878672163, 11699.259547884578], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 9, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el103161290039688656", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290043079472", "color": "#1A5465", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290043080048", "color": "#2A9D8F", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161289998985280", "color": "#1A5465", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290043294304", "color": "#2A9D8F", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}], "paths": [{"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "axes", "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "id": "el103161290042699040", "dasharray": "none", "alpha": 0.8, "facecolor": "rgba(255, 255, 255, 0.8)", "edgecolor": "rgba(204, 204, 204, 0.8)", "edgewidth": 1.0, "zorder": 1000000.0}], "markers": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290043079472pts", "facecolor": "#1A5465", "edgecolor": "#1A5465", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290043080048pts", "facecolor": "#2A9D8F", "edgecolor": "#2A9D8F", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[0.0, 4.242640687119286], [2.545584412271571, 0.0], [0.0, -4.242640687119286], [-2.545584412271571, 0.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161289998985280pts", "facecolor": "#1A5465", "edgecolor": "#1A5465", "edgewidth": 1.0, "alpha": 0.5, "zorder": 1000002.0, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290043294304pts", "facecolor": "#2A9D8F", "edgecolor": "#2A9D8F", "edgewidth": 1.0, "alpha": 0.5, "zorder": 1000002.0, "markerpath": [[[0.0, 4.242640687119286], [2.545584412271571, 0.0], [0.0, -4.242640687119286], [-2.545584412271571, 0.0]], ["M", "L", "L", "L", "Z"]]}], "texts": [{"text": "t", "position": [0.5, -0.12385762385762387], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "hanging", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el103161290022040160"}, {"text": "y", "position": [-0.15340501792114694, 0.5], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -90.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el103161290042703744"}, {"text": "Euler vs RK4 - Ejercicio 1 - Inversi\u00f3n a 5 a\u00f1os - h = 0.5", "position": [ ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://d3js.org/d3.v5"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.5.10.js", function(){
#
#          mpld3.draw_figure("fig_el1031612900424268161281742260", {"width": 750.0, "height": 450.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-0.25, 5.25], "ylim": [9919.082878672163, 11699.259547884578], "xdomain": [-0.25, 5.25], "ydomain": [9919.082878672163, 11699.259547884578], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 9, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el1031612900

# %% [markdown]
# A 5 años, con una tasa de interés del 3% anual, capitalizada semestralmente, $10,000 dólares se transformaron en $11,605.41 con el método de Euler y a $11,618.34 con el método de Runge-Kutta.

# %% [markdown]
# ### Para 10 años

# %%
tn = 10
name = f"Ejercicio 1 - Inversión a {tn} años - h = {h}"

# %%
euler_vs_RK4(name, i, t0, tn, h, y0, plot=True)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1031612900316039529921103481"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1031612900316039529921103481", {"width": 750.0, "height": 450.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-0.5, 10.5], "ylim": [9825.070596296358, 13673.517477776475], "xdomain": [-0.5, 10.5], "ydomain": [9825.070596296358, 13673.517477776475], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 10, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el103161290043449584", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290043453856", "color": "#1A5465", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290044033696", "color": "#2A9D8F", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161290044034464", "color": "#1A5465", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290044035568", "color": "#2A9D8F", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}], "paths": [{"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "axes", "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "id": "el103161290043450448", "dasharray": "none", "alpha": 0.8, "facecolor": "rgba(255, 255, 255, 0.8)", "edgecolor": "rgba(204, 204, 204, 0.8)", "edgewidth": 1.0, "zorder": 1000000.0}], "markers": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290043453856pts", "facecolor": "#1A5465", "edgecolor": "#1A5465", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290044033696pts", "facecolor": "#2A9D8F", "edgecolor": "#2A9D8F", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[0.0, 4.242640687119286], [2.545584412271571, 0.0], [0.0, -4.242640687119286], [-2.545584412271571, 0.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161290044034464pts", "facecolor": "#1A5465", "edgecolor": "#1A5465", "edgewidth": 1.0, "alpha": 0.5, "zorder": 1000002.0, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290044035568pts", "facecolor": "#2A9D8F", "edgecolor": "#2A9D8F", "edgewidth": 1.0, "alpha": 0.5, "zorder": 1000002.0, "markerpath": [[[0.0, 4.242640687119286], [2.545584412271571, 0.0], [0.0, -4.242640687119286], [-2.545584412271571, 0.0]], ["M", "L", "L", "L", "Z"]]}], "texts": [{"text": "t", "position": [0.5, -0.12385762385762387], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "hanging", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el103161290030501808"}, {"text": "y", "position": [-0.15340501792114694, 0.5], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -90.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el103161290043608336"}, {"text": "Euler vs RK4 - Ejercicio 1 - Inversi\u00f3n a 10 a\u00f1os - h = 0.5", "position": [ ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://d3js.org/d3.v5"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.5.10.js", function(){
#
#          mpld3.draw_figure("fig_el1031612900316039529921103481", {"width": 750.0, "height": 450.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-0.5, 10.5], "ylim": [9825.070596296358, 13673.517477776475], "xdomain": [-0.5, 10.5], "ydomain": [9825.070596296358, 13673.517477776475], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickfor

# %% [markdown]
# A 10 años, con una tasa de interés del 3% anual, capitalizada semestralmente, $10,000 dólares se transformaron en $13,468.55 con el método de Euler y a $13,498.59 con el método de Runge-Kutta.

# %% [markdown]
# ### Para 15 años

# %%
tn = 15
name = f"Ejercicio 1 - Inversión a {tn} años - h = {h}"

# %%
euler_vs_RK4(name, i, t0, tn, h, y0, plot=True)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1031612900437743841584340743"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1031612900437743841584340743", {"width": 750.0, "height": 450.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-0.75, 15.75], "ylim": [9715.843907401933, 15967.277944559393], "xdomain": [-0.75, 15.75], "ydomain": [9715.843907401933, 15967.277944559393], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 10, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el103161290043457024", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290079336688", "color": "#1A5465", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290079337216", "color": "#2A9D8F", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161290079337648", "color": "#1A5465", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290079568288", "color": "#2A9D8F", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}], "paths": [{"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "axes", "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "id": "el103161290079151568", "dasharray": "none", "alpha": 0.8, "facecolor": "rgba(255, 255, 255, 0.8)", "edgecolor": "rgba(204, 204, 204, 0.8)", "edgewidth": 1.0, "zorder": 1000000.0}], "markers": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290079336688pts", "facecolor": "#1A5465", "edgecolor": "#1A5465", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290079337216pts", "facecolor": "#2A9D8F", "edgecolor": "#2A9D8F", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[0.0, 4.242640687119286], [2.545584412271571, 0.0], [0.0, -4.242640687119286], [-2.545584412271571, 0.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161290079337648pts", "facecolor": "#1A5465", "edgecolor": "#1A5465", "edgewidth": 1.0, "alpha": 0.5, "zorder": 1000002.0, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290079568288pts", "facecolor": "#2A9D8F", "edgecolor": "#2A9D8F", "edgewidth": 1.0, "alpha": 0.5, "zorder": 1000002.0, "markerpath": [[[0.0, 4.242640687119286], [2.545584412271571, 0.0], [0.0, -4.242640687119286], [-2.545584412271571, 0.0]], ["M", "L", "L", "L", "Z"]]}], "texts": [{"text": "t", "position": [0.5, -0.12385762385762387], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "hanging", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el103161290044036336"}, {"text": "y", "position": [-0.15340501792114694, 0.5], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -90.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el103161290079151808"}, {"text": "Euler vs RK4 - Ejercicio 1 - Inversi\u00f3n a 15 a\u00f1os - h = 0.5", "position ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://d3js.org/d3.v5"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v

# %% [markdown]
# A 15 años, con una tasa de interés del 3% anual, capitalizada semestralmente, $10,000 dólares se transformaron en $15,630.80 con el método de Euler y a $15,683.12 con el método de Runge-Kutta.

# %% [markdown]
# # Ejercicio 2

# %% [markdown]
# Si se invierten 500 dólares a una tasa de interés del 3.75% anual, capitalizada trimestralmente, encuentra el valor de la inversión después del número dado de años. Primero utiliza el método de Euler y luego el método RK4. Grafica la solución numérica con ambos métodos. Superpone ambas curvas de solución en el mismo sistema de coordenadas. Si es posible, utiliza un color diferente para cada curva. Interpreta la solución.
#    - a) 1 año
#    - b) 2 años
#    - c) 10 años

# %%
def i(t, y):
    return 0.0375 * y

t0 = 0 
y0 = 500
h = 0.25

# %% [markdown]
# ### Para 1 año

# %%
tn = 1
name = f"Ejercicio 2 - Inversión a {tn} año - h = {h}"

# %%
euler_vs_RK4(name, i, t0, tn, h, y0, plot=True)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1031612900793239682111926696"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1031612900793239682111926696", {"width": 750.0, "height": 450.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-0.05, 1.05], "ylim": [499.04470007301654, 520.0612984666527], "xdomain": [-0.05, 1.05], "ydomain": [499.04470007301654, 520.0612984666527], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el103161290043296656", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290079906048", "color": "#1A5465", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290079906480", "color": "#2A9D8F", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161290079907152", "color": "#1A5465", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290079908256", "color": "#2A9D8F", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}], "paths": [{"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "axes", "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "id": "el103161290079724624", "dasharray": "none", "alpha": 0.8, "facecolor": "rgba(255, 255, 255, 0.8)", "edgecolor": "rgba(204, 204, 204, 0.8)", "edgewidth": 1.0, "zorder": 1000000.0}], "markers": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290079906048pts", "facecolor": "#1A5465", "edgecolor": "#1A5465", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290079906480pts", "facecolor": "#2A9D8F", "edgecolor": "#2A9D8F", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[0.0, 4.242640687119286], [2.545584412271571, 0.0], [0.0, -4.242640687119286], [-2.545584412271571, 0.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161290079907152pts", "facecolor": "#1A5465", "edgecolor": "#1A5465", "edgewidth": 1.0, "alpha": 0.5, "zorder": 1000002.0, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290079908256pts", "facecolor": "#2A9D8F", "edgecolor": "#2A9D8F", "edgewidth": 1.0, "alpha": 0.5, "zorder": 1000002.0, "markerpath": [[[0.0, 4.242640687119286], [2.545584412271571, 0.0], [0.0, -4.242640687119286], [-2.545584412271571, 0.0]], ["M", "L", "L", "L", "Z"]]}], "texts": [{"text": "t", "position": [0.5, -0.12385762385762387], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "hanging", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el103161290043610160"}, {"text": "y", "position": [-0.10781362007168457, 0.5], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -90.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el103161290079569536"}, {"text": "Euler vs RK4 - Ejercicio 2 - Inversi\u00f3n a 1 a\u00f1o - h = 0.25", "position": [ ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://d3js.org/d3.v5"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.5.10.js", function(){
#
#          mpld3.draw_figure("fig_el1031612900793239682111926696", {"width": 750.0, "height": 450.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-0.05, 1.05], "ylim": [499.04470007301654, 520.0612984666527], "xdomain": [-0.05, 1.05], "ydomain": [499.04470007301654, 520.0612984666527], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el103161290043296656", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290079906048", "color": "#1A5465", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "

# %% [markdown]
# A un año, con una tasa de interés del 3.75% anual, capitalizada trimestralmente, $500 dólares se transformaron en $519.02 con el método de Euler y a $519.11 con el método de Runge-Kutta.

# %% [markdown]
# ### Para 2 años

# %%
tn = 2
name = f"Ejercicio 2 - Inversión a {tn} años - h = {h}"

# %%
euler_vs_RK4(name, i, t0, tn, h, y0, plot=True)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1031612900848358082713020482"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1031612900848358082713020482", {"width": 750.0, "height": 450.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-0.1, 2.1], "ylim": [498.0528962280133, 540.8891792117208], "xdomain": [-0.1, 2.1], "ydomain": [498.0528962280133, 540.8891792117208], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 11, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el103161290084937664", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290085001856", "color": "#1A5465", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290085006224", "color": "#2A9D8F", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161290079270048", "color": "#1A5465", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290085254064", "color": "#2A9D8F", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}], "paths": [{"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "axes", "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "id": "el103161290084837968", "dasharray": "none", "alpha": 0.8, "facecolor": "rgba(255, 255, 255, 0.8)", "edgecolor": "rgba(204, 204, 204, 0.8)", "edgewidth": 1.0, "zorder": 1000000.0}], "markers": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290085001856pts", "facecolor": "#1A5465", "edgecolor": "#1A5465", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290085006224pts", "facecolor": "#2A9D8F", "edgecolor": "#2A9D8F", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[0.0, 4.242640687119286], [2.545584412271571, 0.0], [0.0, -4.242640687119286], [-2.545584412271571, 0.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161290079270048pts", "facecolor": "#1A5465", "edgecolor": "#1A5465", "edgewidth": 1.0, "alpha": 0.5, "zorder": 1000002.0, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290085254064pts", "facecolor": "#2A9D8F", "edgecolor": "#2A9D8F", "edgewidth": 1.0, "alpha": 0.5, "zorder": 1000002.0, "markerpath": [[[0.0, 4.242640687119286], [2.545584412271571, 0.0], [0.0, -4.242640687119286], [-2.545584412271571, 0.0]], ["M", "L", "L", "L", "Z"]]}], "texts": [{"text": "t", "position": [0.5, -0.12385762385762387], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "hanging", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el103161290084933632"}, {"text": "y", "position": [-0.10781362007168457, 0.5], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -90.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el103161290079910704"}, {"text": "Euler vs RK4 - Ejercicio 2 - Inversi\u00f3n a 2 a\u00f1os - h = 0.25", "position": [0.5, ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://d3js.org/d3.v5"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.5.10.js", function(){
#
#          mpld3.draw_figure("fig_el1031612900848358082713020482", {"width": 750.0, "height": 450.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-0.1, 2.1], "ylim": [498.0528962280133, 540.8891792117208], "xdomain": [-0.1, 2.1], "ydomain": [498.0528962280133, 540.8891792117208], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 11, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el103161290084937664", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103

# %% [markdown]
# A dos años, con una tasa de interés del 3.75% anual, capitalizada trimestralmente, $500 dólares se transformaron en $538.75 con el método de Euler y a $538.94 con el método de Runge-Kutta.

# %% [markdown]
# ###  Para 10 años

# %%
tn = 10
name = f"Ejercicio 2 - Inversión a {tn} años - h = {h}"

# %%
euler_vs_RK4(name, i, t0, tn, h, y0, plot=True)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1031612900798972165538464886"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1031612900798972165538464886", {"width": 750.0, "height": 450.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-0.5, 10.5], "ylim": [488.6252146354162, 738.8704926562596], "xdomain": [-0.5, 10.5], "ydomain": [488.6252146354162, 738.8704926562596], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el103161290085256224", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290085622048", "color": "#1A5465", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290085622672", "color": "#2A9D8F", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161290085623344", "color": "#1A5465", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290085624352", "color": "#2A9D8F", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}], "paths": [{"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "axes", "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "id": "el103161290085351552", "dasharray": "none", "alpha": 0.8, "facecolor": "rgba(255, 255, 255, 0.8)", "edgecolor": "rgba(204, 204, 204, 0.8)", "edgewidth": 1.0, "zorder": 1000000.0}], "markers": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290085622048pts", "facecolor": "#1A5465", "edgecolor": "#1A5465", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290085622672pts", "facecolor": "#2A9D8F", "edgecolor": "#2A9D8F", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[0.0, 4.242640687119286], [2.545584412271571, 0.0], [0.0, -4.242640687119286], [-2.545584412271571, 0.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161290085623344pts", "facecolor": "#1A5465", "edgecolor": "#1A5465", "edgewidth": 1.0, "alpha": 0.5, "zorder": 1000002.0, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290085624352pts", "facecolor": "#2A9D8F", "edgecolor": "#2A9D8F", "edgewidth": 1.0, "alpha": 0.5, "zorder": 1000002.0, "markerpath": [[[0.0, 4.242640687119286], [2.545584412271571, 0.0], [0.0, -4.242640687119286], [-2.545584412271571, 0.0]], ["M", "L", "L", "L", "Z"]]}], "texts": [{"text": "t", "position": [0.5, -0.12385762385762387], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "hanging", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el103161290085506640"}, {"text": "y", "position": [-0.10802867383512543, 0.5], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -90.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el103161290085505584"}, {"text": "Euler vs RK4 - Ejercicio 2 - Inversi\u00f3n a 10 a\u00f1os - h = 0.25", "position": [0. ...

# %% [markdown]
# A diez años, con una tasa de interés del 3.75% anual, capitalizada trimestralmente, $500 dólares se transformaron en $726.23 con el método de Euler y a $726.50 con el método de Runge-Kutta.

# %% [markdown]
# # Ejercicio 3

# %% [markdown]
# Considera el modelo simple de combustión dado por
#    $$
#    y' = y^2 - y^3, \quad y(0) = y_0, \quad 0 \leq t \leq \frac{2}{y_0}
#    $$
#    donde $y$ es el radio de la bola de llama. Utiliza RK4 y el método de Euler para investigar el modelo de la llama con estos parámetros: $y_0 = \frac{1}{1000}$ y $h = \frac{t_{final}}{2000}$. Grafica la solución numérica con ambos métodos numéricos. Superpone ambas curvas de solución en el mismo sistema de coordenadas. Si es posible, utiliza un color diferente para cada curva. ¿Para qué valor de $t$ alcanza el radio el valor de 0.90?

# %%
def combustion_model(t, y):
    return y**2 - y**3

y0 = 1 / 1000
t0 = 0
t_final = 2 / y0
h = t_final / 2000
name = "Ejercicio 3 - Modelo de combustión"

euler_vs_RK4(name, combustion_model, t0, t_final, h, y0, plot=True)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1031612900853667685807184389"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1031612900853667685807184389", {"width": 750.0, "height": 450.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-100.0, 2100.0], "ylim": [-0.04895, 1.04995], "xdomain": [-100.0, 2100.0], "ydomain": [-0.04895, 1.04995], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 11, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el103161290085835664", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290089000368", "color": "#1A5465", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290089001040", "color": "#2A9D8F", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161290089002000", "color": "#1A5465", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290089003056", "color": "#2A9D8F", "linewidth": 1.5, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}], "paths": [{"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "axes", "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "id": "el103161290089001328", "dasharray": "none", "alpha": 0.8, "facecolor": "rgba(255, 255, 255, 0.8)", "edgecolor": "rgba(204, 204, 204, 0.8)", "edgewidth": 1.0, "zorder": 1000000.0}], "markers": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290089000368pts", "facecolor": "#1A5465", "edgecolor": "#1A5465", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290089001040pts", "facecolor": "#2A9D8F", "edgecolor": "#2A9D8F", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[0.0, 4.242640687119286], [2.545584412271571, 0.0], [0.0, -4.242640687119286], [-2.545584412271571, 0.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161290089002000pts", "facecolor": "#1A5465", "edgecolor": "#1A5465", "edgewidth": 1.0, "alpha": 0.5, "zorder": 1000002.0, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290089003056pts", "facecolor": "#2A9D8F", "edgecolor": "#2A9D8F", "edgewidth": 1.0, "alpha": 0.5, "zorder": 1000002.0, "markerpath": [[[0.0, 4.242640687119286], [2.545584412271571, 0.0], [0.0, -4.242640687119286], [-2.545584412271571, 0.0]], ["M", "L", "L", "L", "Z"]]}], "texts": [{"text": "t", "position": [0.5, -0.12385762385762387], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "hanging", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el103161290088820864"}, {"text": "y", "position": [-0.09663082437275985, 0.5], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -90.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el103161290088812032"}, {"text": "Euler vs RK4 - Ejercicio 3 - Modelo de combusti\u00f3n", "position": [0.5, 1.0360750360750361], "coordinates": "axes ...

# %% [markdown]
# En el modelo de combustión simple, el radio de la llama llega a $0.90$ entre $1013$ y $1014$ con el método Euler, y en $1014$ con el método de RK4.
#
#
# | x_i   | y_i Euler | y_i RK4 |
# |-------|-----------|---------|
# | 995.0 | 0.07      | 0.1     |
# | 996.0 | 0.08      | 0.11    |
# | 997.0 | 0.08      | 0.13    |
# | 998.0 | 0.09      | 0.14    |
# | 999.0 | 0.1       | 0.16    |
# | 1000.0| 0.11      | 0.18    |
# | 1001.0| 0.12      | 0.22    |
# | 1002.0| 0.13      | 0.26    |
# | 1003.0| 0.14      | 0.32    |
# | 1004.0| 0.16      | 0.4     |
# | 1005.0| 0.18      | 0.51    |
# | 1006.0| 0.21      | 0.65    |
# | 1007.0| 0.25      | 0.79    |
# | 1008.0| 0.29      | 0.9     |
# | 1009.0| 0.35      | 0.96    |
# | 1010.0| 0.43      | 0.98    |
# | 1011.0| 0.54      | 0.99    |
# | 1012.0| 0.67      | 1.0     |
# | 1013.0| 0.82      | 1.0     |
# | 1014.0| 0.94      | 1.0     |
# | 1015.0| 0.99      | 1.0     |
# | 1016.0| 1.0       | 1.0     |

# %% [markdown]
# # Ejercicio 4

# %% [markdown]
# Considerando
#    $$
#    y' = 2xy, \quad y(1) = 1
#    $$
#    calcula $y(1.5)$. Utiliza RK4 y el método de Euler para obtener una aproximación de cuatro decimales del valor indicado. Primero, utiliza $h = 0.1$ y luego utiliza $h = 0.05$. Encuentra una solución analítica explícita para cada problema de valor inicial y luego construye tablas para calcular el error de cada método y todos los valores de la partición. Interpreta la solución. Grafica la solución numérica con ambos métodos y la solución analítica. Superpone las tres curvas de solución en el mismo sistema de coordenadas.

# %% [markdown]
# ### Solución de la EDO

# %% [markdown]
# [mathdf.com](https://mathdf.com/dif/es/#expr=y'%3D2xy&func=y&arg=x&vals=1%3B1)
#
# $$y={e}^{{x}^{2}-1}, \text{   } y_{0}\left(1\right)=1$$

# %% [markdown]
# ### Parámetros

# %%
def function(x, y):
    return 2 * x * y

f = 'exp(x**2-1)'

t0 = 1
y0 = 1
tn = 1.5

# %% [markdown]
# ### Para $h = 0.1$

# %%
h = 0.1
name = 'Ejercicio 4 - h = 0.1'

# %%
compare_methods(name, f, function, t0, tn, h, y0)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1031612900858362885322489444"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1031612900858362885322489444", {"width": 750.0, "height": 450.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [0.975, 1.525], "ylim": [0.8754828521269079, 3.6148601053349334], "xdomain": [0.975, 1.525], "ydomain": [0.8754828521269079, 3.6148601053349334], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el103161290089182320", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290614720320", "color": "#50A3A4", "linewidth": 4.0, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290614720992", "color": "#FCAF38", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 3, "coordinates": "data", "id": "el103161290614721472", "color": "#F95335", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161290614722144", "color": "#50A3A4", "linewidth": 4.0, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290614722672", "color": "#FCAF38", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 3, "coordinates": "axes", "id": "el103161290614723872", "color": "#F95335", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}], "paths": [{"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "axes", "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "id": "el103161290614719840", "dasharray": "none", "alpha": 0.8, "facecolor": "rgba(255, 255, 255, 0.8)", "edgecolor": "rgba(204, 204, 204, 0.8)", "edgewidth": 1.0, "zorder": 1000000.0}], "markers": [{"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290614720992pts", "facecolor": "#FCAF38", "edgecolor": "#FCAF38", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data01", "xindex": 0, "yindex": 3, "coordinates": "data", "id": "el103161290614721472pts", "facecolor": "#F95335", "edgecolor": "#F95335", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[0.0, 3.0], [0.7956093000000001, 3.0], [1.5587396123545605, 2.683901074764725], [2.121320343559643, 2.121320343559643], [2.683901074764725, 1.5587396123545605], [3.0, 0.7956093000000001], [3.0, 0.0], [3.0, -0.7956093000000001], [2.683901074764725, -1.5587396123545605], [2.121320343559643, -2.121320343559643], [1.5587396123545605, -2.683901074764725], [0.7956093000000001, -3.0], [0.0, -3.0], [-0.7956093000000001, -3.0], [-1.5587396123545605, -2.683901074764725], [-2.121320343559643, -2.121320343559643], [-2.683901074764725, -1.5587396123545605], [-3.0, -0.7956093000000001], [-3.0, 0.0], [-3.0, 0.7956093000000001], [-2.683901074764725, 1.5587396123545605], [-2.121320343559643, 2.121320343559643], [-1.5587396123545605, 2.683901074764725], [-0.7956093000000001, 3.0], [0.0, 3.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290614722672pts" ...

# %%
error_euler(name, f, function, t0, tn, h, y0)
# Out:
# <table>
#     <caption>Error Analysis for Euler  Ejercicio 4 - h = 0.1</caption>
#     <thead>
#         <tr>
#             <th>x_i</th>
#             <th>y_i Exact</th>
#             <th>y_i Euler</th>
#             <th>Absolute E</th>
#             <th>Relative E</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1.0</td>
#             <td>1.0</td>
#             <td>1.0</td>
#             <td>0.0</td>
#             <td>0.0</td>
#         </tr>
#         <tr>
#             <td>1.1</td>
#             <td>1.2337</td>
#             <td>1.2</td>
#             <td>0.0337</td>
#             <td>0.0273</td>
#         </tr>
#         <tr>
#             <td>1.2</td>
#             <td>1.5527</td>
#             <td>1.464</td>
#             <td>0.0887</td>
#             <td>0.0571</td>
#         </tr>
#         <tr>
#             <td>1.3</td>
#             <td>1.9937</td>
#             <td>1.8154</td>
#             <td>0.1784</td>
#             <td>0.0895</td>
#         </tr>
#         <tr>
#             <td>1.4</td>
#             <td>2.6117</td>
#             <td>2.2874</td>
#             <td>0.3243</td>
#             <td>0.1242</td>
#         </tr>
#         <tr>
#             <td>1.5</td>
#             <td>3.4903</td>
#             <td>2.9278</td>
#             <td>0.5625</td>
#             <td>0.1612</td>
#         </tr>
#     </tbody>
# </table>

# %%
error_rk4(name, f, function, t0, tn, h, y0)
# Out:
# <table>
#     <caption>Error Analysis for RK4  Ejercicio 4 - h = 0.1</caption>
#     <thead>
#         <tr>
#             <th>x_i</th>
#             <th>y_i Exact</th>
#             <th>y_i RK4</th>
#             <th>Absolute E</th>
#             <th>Relative E</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1.0</td>
#             <td>1.0</td>
#             <td>1.0</td>
#             <td>0.0</td>
#             <td>0.0</td>
#         </tr>
#         <tr>
#             <td>1.1</td>
#             <td>1.23</td>
#             <td>1.23</td>
#             <td>0.0</td>
#             <td>0.0</td>
#         </tr>
#         <tr>
#             <td>1.2</td>
#             <td>1.55</td>
#             <td>1.55</td>
#             <td>0.0</td>
#             <td>0.0</td>
#         </tr>
#         <tr>
#             <td>1.3</td>
#             <td>1.99</td>
#             <td>1.99</td>
#             <td>0.0</td>
#             <td>0.0</td>
#         </tr>
#         <tr>
#             <td>1.4</td>
#             <td>2.61</td>
#             <td>2.61</td>
#             <td>0.0001</td>
#             <td>0.0</td>
#         </tr>
#         <tr>
#             <td>1.5</td>
#             <td>3.49</td>
#             <td>3.49</td>
#             <td>0.0001</td>
#             <td>0.0</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ### Para $h = 0.05$

# %%
h = 0.05
name = 'Ejercicio 4 - h = 0.05'

# %%
compare_methods(name, f, function, t0, tn, h, y0)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el103161290613567376682376890"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el103161290613567376682376890", {"width": 750.0, "height": 450.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [0.975, 1.525], "ylim": [0.8754828521269079, 3.6148601053349334], "xdomain": [0.975, 1.525], "ydomain": [0.8754828521269079, 3.6148601053349334], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el103161290085512544", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290615076624", "color": "#50A3A4", "linewidth": 4.0, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290615078016", "color": "#FCAF38", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 3, "coordinates": "data", "id": "el103161290615078736", "color": "#F95335", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161290615073024", "color": "#50A3A4", "linewidth": 4.0, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290616751504", "color": "#FCAF38", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 3, "coordinates": "axes", "id": "el103161290616752704", "color": "#F95335", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}], "paths": [{"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "axes", "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "id": "el103161290614729296", "dasharray": "none", "alpha": 0.8, "facecolor": "rgba(255, 255, 255, 0.8)", "edgecolor": "rgba(204, 204, 204, 0.8)", "edgewidth": 1.0, "zorder": 1000000.0}], "markers": [{"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290615078016pts", "facecolor": "#FCAF38", "edgecolor": "#FCAF38", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data01", "xindex": 0, "yindex": 3, "coordinates": "data", "id": "el103161290615078736pts", "facecolor": "#F95335", "edgecolor": "#F95335", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[0.0, 3.0], [0.7956093000000001, 3.0], [1.5587396123545605, 2.683901074764725], [2.121320343559643, 2.121320343559643], [2.683901074764725, 1.5587396123545605], [3.0, 0.7956093000000001], [3.0, 0.0], [3.0, -0.7956093000000001], [2.683901074764725, -1.5587396123545605], [2.121320343559643, -2.121320343559643], [1.5587396123545605, -2.683901074764725], [0.7956093000000001, -3.0], [0.0, -3.0], [-0.7956093000000001, -3.0], [-1.5587396123545605, -2.683901074764725], [-2.121320343559643, -2.121320343559643], [-2.683901074764725, -1.5587396123545605], [-3.0, -0.7956093000000001], [-3.0, 0.0], [-3.0, 0.7956093000000001], [-2.683901074764725, 1.5587396123545605], [-2.121320343559643, 2.121320343559643], [-1.5587396123545605, 2.683901074764725], [-0.7956093000000001, 3.0], [0.0, 3.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290616751504pts", ...

# %%
error_euler(name, f, function, t0, tn, h, y0)
# Out:
# <table>
#     <caption>Error Analysis for Euler  Ejercicio 4 - h = 0.05</caption>
#     <thead>
#         <tr>
#             <th>x_i</th>
#             <th>y_i Exact</th>
#             <th>y_i Euler</th>
#             <th>Absolute E</th>
#             <th>Relative E</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1.0</td>
#             <td>1.0</td>
#             <td>1.0</td>
#             <td>0.0</td>
#             <td>0.0</td>
#         </tr>
#         <tr>
#             <td>1.05</td>
#             <td>1.1079</td>
#             <td>1.1</td>
#             <td>0.0079</td>
#             <td>0.0072</td>
#         </tr>
#         <tr>
#             <td>1.1</td>
#             <td>1.2337</td>
#             <td>1.2155</td>
#             <td>0.0182</td>
#             <td>0.0147</td>
#         </tr>
#         <tr>
#             <td>1.15</td>
#             <td>1.3806</td>
#             <td>1.3492</td>
#             <td>0.0314</td>
#             <td>0.0227</td>
#         </tr>
#         <tr>
#             <td>1.2</td>
#             <td>1.5527</td>
#             <td>1.5044</td>
#             <td>0.0483</td>
#             <td>0.0311</td>
#         </tr>
#         <tr>
#             <td>1.25</td>
#             <td>1.7551</td>
#             <td>1.6849</td>
#             <td>0.0702</td>
#             <td>0.04</td>
#         </tr>
#         <tr>
#             <td>1.3</td>
#             <td>1.9937</td>
#             <td>1.8955</td>
#             <td>0.0982</td>
#             <td>0.0493</td>
#         </tr>
#         <tr>
#             <td>1.35</td>
#             <td>2.2762</td>
#             <td>2.1419</td>
#             <td>0.1343</td>
#             <td>0.059</td>
#         </tr>
#         <tr>
#             <td>1.4</td>
#             <td>2.6117</td>
#             <td>2.4311</td>
#             <td>0.1806</td>
#             <td>0.0692</td>
#         </tr>
#         <tr>
#             <td>1.45</td>
#             <td>3.0117</td>
#             <td>2.7714</td>
#             <td>0.2403</td>
#             <td>0.0798</td>
#         </tr>
#         <tr>
#             <td>1.5</td>
#             <td>3.4903</td>
#             <td>3.1733</td>
#             <td>0.3171</td>
#             <td>0.0908</td>
#         </tr>
#     </tbody>
# </table>

# %%
error_rk4(name, f, function, t0, tn, h, y0)
# Out:
# <table>
#     <caption>Error Analysis for RK4  Ejercicio 4 - h = 0.05</caption>
#     <thead>
#         <tr>
#             <th>x_i</th>
#             <th>y_i Exact</th>
#             <th>y_i RK4</th>
#             <th>Absolute E</th>
#             <th>Relative E</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1.0</td>
#             <td>1.0</td>
#             <td>1.0</td>
#             <td>0.0</td>
#             <td>0.0</td>
#         </tr>
#         <tr>
#             <td>1.05</td>
#             <td>1.11</td>
#             <td>1.11</td>
#             <td>0.0</td>
#             <td>0.0</td>
#         </tr>
#         <tr>
#             <td>1.1</td>
#             <td>1.23</td>
#             <td>1.23</td>
#             <td>0.0</td>
#             <td>0.0</td>
#         </tr>
#         <tr>
#             <td>1.15</td>
#             <td>1.38</td>
#             <td>1.38</td>
#             <td>0.0</td>
#             <td>0.0</td>
#         </tr>
#         <tr>
#             <td>1.2</td>
#             <td>1.55</td>
#             <td>1.55</td>
#             <td>0.0</td>
#             <td>0.0</td>
#         </tr>
#         <tr>
#             <td>1.25</td>
#             <td>1.76</td>
#             <td>1.76</td>
#             <td>0.0</td>
#             <td>0.0</td>
#         </tr>
#         <tr>
#             <td>1.3</td>
#             <td>1.99</td>
#             <td>1.99</td>
#             <td>0.0</td>
#             <td>0.0</td>
#         </tr>
#         <tr>
#             <td>1.35</td>
#             <td>2.28</td>
#             <td>2.28</td>
#             <td>0.0</td>
#             <td>0.0</td>
#         </tr>
#         <tr>
#             <td>1.4</td>
#             <td>2.61</td>
#             <td>2.61</td>
#             <td>0.0</td>
#             <td>0.0</td>
#         </tr>
#         <tr>
#             <td>1.45</td>
#             <td>3.01</td>
#             <td>3.01</td>
#             <td>0.0</td>
#             <td>0.0</td>
#         </tr>
#         <tr>
#             <td>1.5</td>
#             <td>3.49</td>
#             <td>3.49</td>
#             <td>0.0</td>
#             <td>0.0</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# Concluimos que el método de Runge-Kutta es más cercano al valor verdadero que el método de Euler.

# %% [markdown]
# # Ejercicio 5

# %% [markdown]
# Considerando
#    $$
#    y' = y(10 - 2y), \quad y(0) = 1
#    $$
#    obtén la solución numérica para el problema de valor inicial $IVP$ dado. Primero, utiliza el método de Euler y luego el método RK4. Utiliza $h = 0.25$ en cada caso. Superpone ambas curvas de solución en el mismo sistema de coordenadas. Si es posible, utiliza un color diferente para cada curva. Repite, utilizando $h = 0.1$ y $h = 0.05$.

# %% [markdown]
# ### Solución de la EDO:

# %% [markdown]
# [mathdf.com](https://mathdf.com/dif/es/#expr=y'%3Dy(10-2y)&func=y&arg=x&vals=0%3B1)
#
# $$
# y=\dfrac{5}{-\dfrac{{e}^{10\,x}}{4}-1}+5, \text{   } y_{0}\left(0\right)=1
# $$

# %% [markdown]
# ### Parámetros

# %%
def growth_model(t, y):
    return y * (10 - 2 * y)

f = ' 5 / (-(exp(10 * x) / 4) - 1) + 5'

t0 = 0 
y0 = 1
tn = 5

# %% [markdown]
# ### Para $h=0.25$

# %%
name = 'h = 0.25'
h = 0.25

# %%
compare_methods(name, f, growth_model, t0, tn, h, y0)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1031612900356160166354205419"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1031612900356160166354205419", {"width": 750.0, "height": 450.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-0.25, 5.25], "ylim": [0.75, 6.25], "xdomain": [-0.25, 5.25], "ydomain": [0.75, 6.25], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el103161290616880496", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290617133760", "color": "#50A3A4", "linewidth": 4.0, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290617134384", "color": "#FCAF38", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 3, "coordinates": "data", "id": "el103161290617135104", "color": "#F95335", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161290617135920", "color": "#50A3A4", "linewidth": 4.0, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290617136880", "color": "#FCAF38", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 3, "coordinates": "axes", "id": "el103161290617138080", "color": "#F95335", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}], "paths": [{"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "axes", "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "id": "el103161290616761008", "dasharray": "none", "alpha": 0.8, "facecolor": "rgba(255, 255, 255, 0.8)", "edgecolor": "rgba(204, 204, 204, 0.8)", "edgewidth": 1.0, "zorder": 1000000.0}], "markers": [{"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290617134384pts", "facecolor": "#FCAF38", "edgecolor": "#FCAF38", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data01", "xindex": 0, "yindex": 3, "coordinates": "data", "id": "el103161290617135104pts", "facecolor": "#F95335", "edgecolor": "#F95335", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[0.0, 3.0], [0.7956093000000001, 3.0], [1.5587396123545605, 2.683901074764725], [2.121320343559643, 2.121320343559643], [2.683901074764725, 1.5587396123545605], [3.0, 0.7956093000000001], [3.0, 0.0], [3.0, -0.7956093000000001], [2.683901074764725, -1.5587396123545605], [2.121320343559643, -2.121320343559643], [1.5587396123545605, -2.683901074764725], [0.7956093000000001, -3.0], [0.0, -3.0], [-0.7956093000000001, -3.0], [-1.5587396123545605, -2.683901074764725], [-2.121320343559643, -2.121320343559643], [-2.683901074764725, -1.5587396123545605], [-3.0, -0.7956093000000001], [-3.0, 0.0], [-3.0, 0.7956093000000001], [-2.683901074764725, 1.5587396123545605], [-2.121320343559643, 2.121320343559643], [-1.5587396123545605, 2.683901074764725], [-0.7956093000000001, 3.0], [0.0, 3.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290617136880pts", "facecolor": "#FCAF38", "edgecolor": "#FCAF38", "edgewid ...

# %% [markdown]
# ### Para $h=0.10$

# %%
name = 'h = 0.10'
h = 0.10

# %%
compare_methods(name, f, growth_model, t0, tn, 0.10, y0)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1031612900856214725341467473"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1031612900856214725341467473", {"width": 750.0, "height": 450.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-0.25, 5.25], "ylim": [0.8, 5.2], "xdomain": [-0.25, 5.25], "ydomain": [0.8, 5.2], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el103161290617140384", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290617562816", "color": "#50A3A4", "linewidth": 4.0, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290617567232", "color": "#FCAF38", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 3, "coordinates": "data", "id": "el103161290617568000", "color": "#F95335", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161290617554560", "color": "#50A3A4", "linewidth": 4.0, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290620699424", "color": "#FCAF38", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 3, "coordinates": "axes", "id": "el103161290620700624", "color": "#F95335", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}], "paths": [{"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "axes", "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "id": "el103161290614870176", "dasharray": "none", "alpha": 0.8, "facecolor": "rgba(255, 255, 255, 0.8)", "edgecolor": "rgba(204, 204, 204, 0.8)", "edgewidth": 1.0, "zorder": 1000000.0}], "markers": [{"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290617567232pts", "facecolor": "#FCAF38", "edgecolor": "#FCAF38", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data01", "xindex": 0, "yindex": 3, "coordinates": "data", "id": "el103161290617568000pts", "facecolor": "#F95335", "edgecolor": "#F95335", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[0.0, 3.0], [0.7956093000000001, 3.0], [1.5587396123545605, 2.683901074764725], [2.121320343559643, 2.121320343559643], [2.683901074764725, 1.5587396123545605], [3.0, 0.7956093000000001], [3.0, 0.0], [3.0, -0.7956093000000001], [2.683901074764725, -1.5587396123545605], [2.121320343559643, -2.121320343559643], [1.5587396123545605, -2.683901074764725], [0.7956093000000001, -3.0], [0.0, -3.0], [-0.7956093000000001, -3.0], [-1.5587396123545605, -2.683901074764725], [-2.121320343559643, -2.121320343559643], [-2.683901074764725, -1.5587396123545605], [-3.0, -0.7956093000000001], [-3.0, 0.0], [-3.0, 0.7956093000000001], [-2.683901074764725, 1.5587396123545605], [-2.121320343559643, 2.121320343559643], [-1.5587396123545605, 2.683901074764725], [-0.7956093000000001, 3.0], [0.0, 3.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290620699424pts", "facecolor": "#FCAF38", "edgecolor": "#FCAF38", "edgewidth": ...

# %% [markdown]
# ### Para $h=0.05$

# %%
name = 'h = 0.05'
h = 0.05

# %%
compare_methods(name, f, growth_model, t0, tn, 0.05, y0)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1031612900888189921626242148"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1031612900888189921626242148", {"width": 750.0, "height": 450.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-0.25, 5.25], "ylim": [0.8, 5.2], "xdomain": [-0.25, 5.25], "ydomain": [0.8, 5.2], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#B0B0B0", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el103161290616874208", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el103161290617357808", "color": "#50A3A4", "linewidth": 4.0, "dasharray": "none", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290617366304", "color": "#FCAF38", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 3, "coordinates": "data", "id": "el103161290617370672", "color": "#F95335", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el103161290614991056", "color": "#50A3A4", "linewidth": 4.0, "dasharray": "none", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290616757696", "color": "#FCAF38", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 3, "coordinates": "axes", "id": "el103161290616762928", "color": "#F95335", "linewidth": 1.5, "dasharray": "6,6", "alpha": 0.5, "zorder": 1000002.0, "drawstyle": "default"}], "paths": [{"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "axes", "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "id": "el103161290617364192", "dasharray": "none", "alpha": 0.8, "facecolor": "rgba(255, 255, 255, 0.8)", "edgecolor": "rgba(204, 204, 204, 0.8)", "edgewidth": 1.0, "zorder": 1000000.0}], "markers": [{"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el103161290617366304pts", "facecolor": "#FCAF38", "edgecolor": "#FCAF38", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[-3.0, 3.0], [3.0, 3.0], [3.0, -3.0], [-3.0, -3.0]], ["M", "L", "L", "L", "Z"]]}, {"data": "data01", "xindex": 0, "yindex": 3, "coordinates": "data", "id": "el103161290617370672pts", "facecolor": "#F95335", "edgecolor": "#F95335", "edgewidth": 1.0, "alpha": 0.5, "zorder": 2, "markerpath": [[[0.0, 3.0], [0.7956093000000001, 3.0], [1.5587396123545605, 2.683901074764725], [2.121320343559643, 2.121320343559643], [2.683901074764725, 1.5587396123545605], [3.0, 0.7956093000000001], [3.0, 0.0], [3.0, -0.7956093000000001], [2.683901074764725, -1.5587396123545605], [2.121320343559643, -2.121320343559643], [1.5587396123545605, -2.683901074764725], [0.7956093000000001, -3.0], [0.0, -3.0], [-0.7956093000000001, -3.0], [-1.5587396123545605, -2.683901074764725], [-2.121320343559643, -2.121320343559643], [-2.683901074764725, -1.5587396123545605], [-3.0, -0.7956093000000001], [-3.0, 0.0], [-3.0, 0.7956093000000001], [-2.683901074764725, 1.5587396123545605], [-2.121320343559643, 2.121320343559643], [-1.5587396123545605, 2.683901074764725], [-0.7956093000000001, 3.0], [0.0, 3.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el103161290616757696pts", "facecolor": "#FCAF38", "edgecolor": "#FCAF38", "edgewidth": ...

# %% [markdown]
# Concluimos que mientras $h$ sea menor, tendremos una mejor aproximación.

# %% [markdown]
# # Exportar los plots

# %%
# multipage("Practica 4.pdf", figs=all_figures)
